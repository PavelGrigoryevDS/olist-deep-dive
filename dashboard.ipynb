# %% [markdown]
# Drill-down возможность:
#
# - Кликнуть на категорию → увидеть динамику
# - Кликнуть на штат → увидеть топ продавцов

# %% [markdown]
# Tooltips с дополнительной аналитикой (например, при наведении на продавца — его основные метрики)

# %% [markdown]
# Основной график: 12–24 месяца (чтобы видеть сезонность и годовой рост).
#
# Доп. фильтры:
# - Переключение между "Месяцами" и "Неделями" (если есть всплески активности, например, Black Friday).
# - Сравнение с прошлым годом (YoY toggle).

# %% [markdown]
# 2. Понимание задачи
#     - Зачем нам нужен дашборд?
#       - Мониторить текущую ситуацию
#       - Определять лидеров и аутсайдеров среди товаров
#       - Понимать активность клиентов
#       - Понимать какие продукты пользуются большим спросом для корректировки маркетинговой активности
# 3. Метрики, срезы и источники данных
#     - Метрики
#       - Динамика во времени
#         - количество продаж
#         - сумма заказа
#         - конверсия в успешную покупку
#         - доля отмененных заказов
#         - средняя цена заказа
#         - количество покупок на покупателя
#         - arppu
#         - количество покупателей
#         - доля новых покупателей
#         - количество продавцов
#         - доля новых продавцов
#         - отношение количества продавцов и покупателей (всех и новых)
#         - количество отзывов
#         - средняя оценка отзыва
#         - nps
#         - доля стоимости доставки в цене заказа
#         - время доставки
#         - время задержки доставки
#         - время до передачи заказа перевозчику
#         - время доставки от перевозчика
#         - доля каждого этапа доставки в общем времени доставки
#         - вес заказа
#         - количество продуктов в заказе (всего и уникальных)
#         - средняя цена продукта в заказе
#         - среднее количество продавцов в заказе
#         - среднее количество категорий в заказе
#       - Покупатели
#         - количество покупателей
#         - среднее количество покупок на одного покупателя
#         - общая сумма покупок на покупателя
#         - средний чек
#         - количество отмененных заказов
#         - доля отмененных заказов
#         - доля повторных покупок
#         - время между покупками
#         - количество продуктов в заказе
#         - средняя цена продукта в заказе
#         - количество отзывов
#         - оценка отзыва
#         - стоимость доставки
#         - время доставки
#         - задержка доставки
#         - вес заказа
#         - время от первой до второй покупки
#         - время от первой до последней покупки
#         - количество месяцев с покупками
#         - максимальное количество месяцев подряд с покупками
#       - Продавцы
#         - Количество проданных продуктов
#         - Количество проданных уникальных продуктов
#         - Суммарная выручка от проданных продуктов
#         - среднее количество продуктов продавца в заказе
#         - суммарная цена всех продуктов в заказе
#         - Средняя цена продукта в заказе
#         - средний вес проданного продукта
#         - время передачи заказа перевозчику
#         - задержка передачи заказа перевозчику
#       - Продажи
#         - Количество заказов
#         - Сумма заказов
#         - Средний чек
#         - Средняя оценка заказа
#         - Средний вес заказа
#         - Количество продуктов в заказе
#         - Средняя цена продукта в заказе
#         - Среднее количество продавцов в заказе
#         - Среднее количество категорий в заказе
#       - Продукты
#         - Количество проданных едениц продукта
#         - Сумма продаж продуктов
#         - Средняя Цена проданных продуктов
#         - Диапозон изменения цены продуктов
#         - Среднее количество продуктов в заказе
#         - Сердний вес продукта
#         - Средний объем продукта
#         - Отношение веса к объему продукта
#       - Отзываы
#         - Количество отзываов
#         - Оценка отзыва
#         - Время ответа на отзыв
#         - nps
#       - Доставка
#         - Стоимость доставки
#         - Расстояние от покупателя до продавца
#         - Время доставки
#           - доля каждого  этапа доставки в общем времени доставки
#           - общее время доставки
#           - задержка доставки
#           - purchase > approve
#           - approve > carrier
#           - carrier > customer
#           - задержка передачи заказа продавцом
#       - Платежи
#         - Количество платежей
#         - Сумма платежей
#         - Количество частей рассрочки в платеже
#     - Срезы
#       - Уровень заказа
#         - время (год, месяц, день недели, время суток, час дня)
#         - статус заказа
#         - задержан ли заказ
#         - отменен ли заказ
#         - доставлен ли заказ
#         - имеет ли заказ рассрочку
#         - типы платежей в заказе
#         - категории продуктов
#         - обобщенные категории продуктов
#         - оценка отзыва
#       - Уровень покупателя
#         - Сегмент клиентов (новые/повторные и прочие)
#         - штат покупателя
#         - город покупателя
#         - Activity Segment
#         - Value Segment
#         - Purchase Frequency Segment
#         - Repeat Segment
#         - Installment Segment
#         - Weight Segment
#       - Уровень платежей
#         - имеет ли рассрочку
#         - тип платежа
#       - Уровень продуктов
#         - категория продукта
#         - обобщенная категория продукта
#       - Уровень продавцов
#         - штат продавца
#         - город продавца
#     - Источники
#       - df_sales (продажи)
#       - df_customers (покупатели)
#       - df_payments (платежи)
#       - df_products (продукты)

# %% [markdown]
# ### Подумать как не просто среднее отобразить а может где-то лучше боксплоты

# %%
- Сделать фильтра периода отображения (по умолчанию сделать последний месяц, но чтобы можно было любой период выбрать)
- Главная страница (Overview)
    - клик на ban переводит на соответствующую страницу
    - ban сумма продаж  за последний месяц + спарклайн за год и yoy
    - ban количество продаж за последний месяц + спарклайн за год и yoy
    - ban средний чек  за последний месяц + спарклайн за год и yoy
    - ban NPS за последний месяц + спарклайн за год и yoy
    - ban количество актинвых покупателей за последний месяц + спарклайн за год и yoy
    - ban доля повторных покупок за последний месяц + спарклайн за год и yoy
    - ban доля задержанных заказов за последний месяц + спарклайн за год и yoy
    - ban время доставки за последний месяц + спарклайн за год и yoy
    - карта по штатам количество продаж, сумма продаж,средний чек, NPS, доля задержанных заказов, количество активных покупателй (выбор метрики параметром)
- Страница продажи
    - ban количество продаж за последний месяц + спарклайн за последний месяц и yoy (линия последнего месяца и линия месяца год назад)
    - ban сумма продаж за последний месяц + спарклайн за последний месяц и yoy (линия последнего месяца и линия месяца год назад)
    - ban средний чек за последний месяц + спарклайн за последний месяц и yoy (линия последнего месяца и линия месяца год назад)
    - ban среднее количество продуктов в заказе за последний месяц + спарклайн за последний месяц и yoy (линия последнего месяца и линия месяца год назад)        
    - Таблица количество заказов / сумма продаж / средний чек по штатам за последний месяц (добавить линию среднего значения по всем)
    - Таблица количество заказов / сумма продаж / средний чек по городам за последний месяц (добавить линию среднего значения по всем)
    - Таблица количество заказов / сумма продаж / средний чек по оценке отзыва за последний месяц (добавить линию среднего значения по всем)
    - Таблица количество заказов / сумма продаж / средний чек по типу платежа за последний месяц (добавить линию среднего значения по всем)
    - Детальная тиблица заказов со всеми метриками
- Страница покупателей
    - ban количество покупателей за последний месяц + спарклайн за последний месяц и yoy (линия последнего месяца и линия месяца год назад)
    - ban количество новых покупателей за последний месяц + спарклайн за последний месяц и yoy (линия последнего месяца и линия месяца год назад)
    - ban доля новых покупателей за последний месяц + спарклайн за последний месяц и yoy (линия последнего месяца и линия месяца год назад)
    - ban ARPPU за последний месяц + спарклайн за последний месяц и yoy (линия последнего месяца и линия месяца год назад)
    - ban среднее количество покупок на покупателя за последний месяц + спарклайн за последний месяц и yoy (линия последнего месяца и линия месяца год назад)
    - ban доля повторных покупок на покупателя за последний месяц + спарклайн за последний месяц и yoy (линия последнего месяца и линия месяца год назад)
    - таблица + bar график количества покупателей и новых по штатам
    - таблица + bar график количества покупателей и новых по городам
    - таблица + bar график количества покупателей и новых по разным сегементам
    - rfm treemap с сегментами
- Страница продуктов
    - ban Средний вес проданного продукта и динамика за год и yoy
    - ban Средний объем проданного продукта и динамика за год и yoy
    - таблица + бар график количество проданных продуктов, сумма продуктов, средняя сумма продуктов по категориям
    - таблица + бар график количество проданных продуктов, сумма продуктов, средняя сумма продуктов по обобщенным категориям
    - ABC анализ
    - Какие 5 обобщенных категорий приносят 80% выручки?
    - Какие 5 категорий приносят 80% выручки?
    - Таблица со всеми метриками продуктов
- Страница доставки
    - ban время доставки за последний месяц + спарклайн за год и yoy
    - ban время от создания до одобрения за последний месяц + спарклайн за год и yoy
    - ban время от одобрения до передачи перевозчику за последний месяц + спарклайн за год и yoy
    - ban время от доставки от перевозчика до покупателя за последний месяц + спарклайн за год и yoy
    - ban задержка доставки за последний месяц + спарклайн за год и yoy
    - ban задержка передачи заказа перевозчику за последний месяц + спарклайн за год и yoy
    - ban доля задержанных заказов за последний месяц + спарклайн за последний месяц и yoy
    - pie сhart (общее за месяц) + stack area по дням за последний месяц доля каждого этапа доставки в общем времени доставки
    - таблица + бар график времени между всеми этапами и обе задержки по штатам
    - таблица + бар график времени между всеми этапами и обе задержки по городам
- Страница Отзывы
    - ban количество отзывов за последний месяц + спарклайн за год и yoy
    - ban средняя оценка отзыва за последний месяц + спарклайн за год и yoy
    - ban время ответа на отзыв за последний месяц + спарклайн за год и yoy
    - ban NPS за последний месяц + спарклайн за последний месяц (линия этого года и прошлого) и yoy
    - таблица плюс бар чарт количество отзывов,оценка отзыва, время ответа на отзыв по штатам
    - таблица плюс бар чарт количество отзывов,оценка отзыва, время ответа на отзыв по городам
    - Word cloud из текстов отзывов для разных оценок (оценка либо вкладкой либо параметром)
    - scatter оценка заказа vs время доставки (цветом подумать какие категории добавить)
- Страница Продавцы
    - ban количество покупателей за последний месяц + спарклайн за последний месяц и yoy (линия последнего месяца и линия месяца год назад)
    - ban доля новых покупателей за последний месяц + спарклайн за последний месяц и yoy (линия последнего месяца и линия месяца год назад)
    - bar количество продавцов по штатам (топ лучших и топ худших)
    - bar количество продавцов по городам (топ лучших и топ худших)
    - Таблица по продавцам со всеми метриками
- Страница Аналитика (Когортный анализ и RFM)
  - Когортный анализ
    - количество заказов
    - Revenue
    - Number of active customers
    - aov
    - apc
    - ретеншн
    - Arppu
    - ltv
  - treemap сементов rfm

# %%
- На каждой странице (где нужно) внизу таблица с детальными метриками и измерениями (измерения лучше вкладками)
- Для обобщенной и обычной категории сделать иерархию
- Например для страницы продавцов будет таблица по продавцам и метрики их (количество прдаж, сумма прода, время передачи перевозчику и прочие метрики)

# %%
- На главной внизу сделать карту бразилии с отображением метрик (метрики выбираются) параметрами (количество продаж, сумма продаж, средний чек, средний отзыв, время доставки, задержка доставки,количество активных покупателей и может ещё какие-то, но важно тут именно главные метрики)
-

# %% [markdown]
# 5.  Для каждого пункта нарисуйте и опишите график, отвечающий на каждый вопрос
#    - На каждый вопрос из предыдущего пункта или на каждое бизнес-решение подбирается визуализация
#    - Для каждого вопроса пишем название графика или иконку (важно, чтобы было понятно что за тип графика) (барчарт, лайнчарт, таблица, фактоид)
#      - Как шли продажи - лайн чарт
#      - Я пониаю что они упали больше чем на 20 процентов - подсвечиваем точки красным ниже этого значения или делаем алерт
#      - Как изменилась метрика Х относительно прошлой недели? - Фактоид с индикатором прироста.
#      - Как менялась доля продукта Х в общем портфеле? - Area-chart во времени и можно все другие категории сделать бледными, а нужную ярче
#      - Какая динамика метрики? - Фактоид + спарклайн.
#      - В каких регионах наибольшее значение меттрики Х? - Бар-chart
#      - Если метрика Х отличается от плаана на 10%, то я звоню менеджеру и выясняю, что случилось. - Таблица с отклонениями, фактом и планом. С возможнсотью сортировки по отклонению. С контактами менеджера.
# 6.  Из этих графиков составте макет
#     - Используем блоки из вопросов и бизнес решений
#     - И для каждого блока помещаем туда набор визуализаций из пункта про визуализации
# 7.  Утвердите макет.
#     - Покажите пользователям макет
#     - Соберите обратную связь.
# 8.  Разработайте протатип
#     - Покажите протатип пользователям
#     - Соберите обратную связь
# 9.  Тестирование. Демо. QA.
#     - Проведите демо дашборда
#     - Проведите тестирование
#     - Настройте процессы QA для данных
# 10. Оценка качества работы
#    - Смотрим как часто и сколько пользователей пользуются (лучше доля пользователей от всех кто должен использовать этот дашборд, чтобы было нормировано)
#    - Проводим опрос среди пользователей (тут лучше проводить опрос через какое-то время, например через месяц, так как в первый момент не очень адекватный могут быть оценки)
# 11. Если у нас несколько дашбордов,то все предыдущее будет относится к каждому дашборду из Dashboard Map
#    - Сначала разрабатываеся Dashboard Map (набор дашбордов и система взаимодействия между ними)
#    - А далее для каждого дашборда проделываются все шаги выше
